# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
from sklearn.model_selection import train_test_split, GridSearchCV, RandomizedSearchCV
import xgboost as xgb
import warnings
warnings.filterwarnings('ignore')
from sklearn.utils.class_weight import compute_class_weight
from sklearn.metrics import classification_report, confusion_matrix

# %%
df = pd.read_parquet('/content/target1_data.parquet')
df.head(10)
# Out:
#    Price  Positive  Negative  Average playtime forever  release_year  \
# 0  19.99  1.945910  2.484907                         0          2008
# 1   0.99  3.988984  1.791759                         0          2017
# 2   5.99  1.386294  0.000000                         0          2020
# 3   0.00  3.931826  2.197225                         0          2020
# 4   0.00  4.477337  3.912023                         0          2021
# 5  10.99  3.091042  2.079442                         0          2022
# 6  14.99  4.343805  1.945910                         0          2020
# 7   3.99  5.420535  3.828641                         1          2014
# 8  23.99  6.380123  5.361292                         1          2019
# 9   0.00  4.997212  4.077537                         1          2016
#
#    release_month  release_quarter  game_age_years  release_season  \
# 0             10                4              17               3
# 1             10                4               8               3
# ...

# %%
x = df.drop(columns=['target_new'])
y = df['target_new']

x_train, x_test, y_train, y_test = train_test_split(x,y,test_size = 0.1, random_state=42)

# %%
dt = xgb.XGBClassifier()
model = dt.fit(x_train,y_train)
model.score(x_test,y_test)
# Out:
# 0.9208984375

# %%
print("x_train shape:", x_train.shape)
print("y_train shape:", y_train.shape)
print("x_test shape:", x_test.shape)
print("y_test shape:", y_test.shape)

print("\nx_train head:")
display(x_train.head())

print("\nx_test head:")
display(x_test.head())

print("\ny_train head:")
display(y_train.head())

print("\ny_test head:")
display(y_test.head())
# Out:
# x_train shape: (55288, 40)
# y_train shape: (55288,)
# x_test shape: (6144, 40)
# y_test shape: (6144,)
#
# x_train head:
#        Price  Positive  Negative  Average playtime forever  release_year  \
# 35376   3.99  1.098612  0.000000                         0          2022
# 35223   9.99  3.091042  0.693147                         0          2019
# 12542   3.99  2.944439  3.367296                         0          2018
# 11459  19.99  2.302585  1.945910                         0          2022
# 26216   4.99  2.564949  2.079442                         0          2020
#
#        release_month  release_quarter  game_age_years  release_season  \
# 35376              5                2               3               1
# 35223              8                3               6               2
# 12542              7                3               7               2
# 11459              6                2               3               2
# ...

# %%
param_grid = {
    'max_depth': [3, 5, 7],
    'learning_rate': [0.01, 0.1, 0.2],
    'n_estimators': [100, 200, 300],
    'subsample': [0.7, 0.8, 0.9],
    'colsample_bytree': [0.7, 0.8, 0.9]
}

xgb_model = xgb.XGBClassifier(
    random_state=42,
    tree_method='hist',
    device='cuda',
    use_label_encoder=False,
    eval_metric='mlogloss'
)

print("XGBoost modeli GPU ayarlarıyla (hist/cuda) hazırlandı.")

# 3. Sınıf Ağırlıklarını Hesapla (Dengesiz veri seti için)
class_weights = compute_class_weight(class_weight='balanced', classes=np.unique(y_train), y=y_train)
class_weight_dict = dict(zip(np.unique(y_train), class_weights))

# Her bir örnek için ağırlık ataması
sample_weights_array = y_train.map(class_weight_dict)

# 4. RandomizedSearchCV Kurulumu
random_search = RandomizedSearchCV(
    estimator=xgb_model,
    param_distributions=param_grid,
    n_iter=20,
    cv=5,
    scoring='f1_weighted',
    verbose=0,
    n_jobs=1,
    random_state=42
)

print("RandomizedSearchCV başlıyor...")

# 5. Eğitimi Başlat
random_search.fit(x_train, y_train, sample_weight=sample_weights_array)

print("Eğitim başarıyla tamamlandı.")
print("En iyi parametreler:", random_search.best_params_)
print("En iyi skor:", random_search.best_score_)
# Out:
# XGBoost modeli GPU ayarlarıyla (hist/cuda) hazırlandı.
# RandomizedSearchCV başlıyor...
# Eğitim başarıyla tamamlandı.
# En iyi parametreler: {'subsample': 0.9, 'n_estimators': 100, 'max_depth': 7, 'learning_rate': 0.1, 'colsample_bytree': 0.9}
# En iyi skor: 0.9184725973978619

# %%
# 1. En iyi modeli RandomizedSearchCV içinden alıyoruz
best_model = random_search.best_estimator_

print("En iyi model parametreleri:", random_search.best_params_)

# 2. Test seti üzerinde tahmin yapıyoruz
y_pred = best_model.predict(x_test)

# 3. Classification Report oluştur ve yazdır
print("\nClassification Report:")
print(classification_report(y_test, y_pred))

# 4. Confusion Matrix oluştur
conf_matrix = confusion_matrix(y_test, y_pred)
print("\nConfusion Matrix:")
print(conf_matrix)

# 5. Görselleştirme (Heatmap)
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues',
            xticklabels=best_model.classes_,
            yticklabels=best_model.classes_)
plt.xlabel('Predicted Label (Tahmin)')
plt.ylabel('True Label (Gerçek)')
plt.title('Confusion Matrix (En İyi XGBoost Modeli)')
plt.show()
# Out:
# En iyi model parametreleri: {'subsample': 0.9, 'n_estimators': 100, 'max_depth': 7, 'learning_rate': 0.1, 'colsample_bytree': 0.9}
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.90      0.96      0.93      1988
#            1       0.89      0.86      0.88      2051
#            2       0.96      0.93      0.95      2105
#
#     accuracy                           0.92      6144
#    macro avg       0.92      0.92      0.92      6144
# weighted avg       0.92      0.92      0.92      6144
#
#
# Confusion Matrix:
# [[1913   75    0]
#  [ 207 1768   76]
#  [   0  140 1965]]

# %%
# sınıf ağırlıklarına göre düzenliyoruz

class_weights = compute_class_weight(class_weight='balanced', classes=np.unique(y_train), y=y_train)
class_weight_dict = dict(zip(np.unique(y_train), class_weights))

print("Orijinal Ağırlıklar:", class_weight_dict)


# class 1 ağırlığını manuel olarak %50 artırıyoruz (1.5 katı).
# Bu sayede model Sınıf 1 hatalarını daha ciddiye alacak.
class_weight_dict[1] = class_weight_dict[1] * 1.5

print("Güncellenmiş (Torpilli) Ağırlıklar:", class_weight_dict)

# Ağırlıkları her bir eğitim örneğine atıyoruz
sample_weights_array = y_train.map(class_weight_dict)


# model hiperparemetreleri ayarlıyoruz
xgb_model = xgb.XGBClassifier(
    random_state=42,
    tree_method='hist',
    device='cuda',
    use_label_encoder=False,
    eval_metric='mlogloss',
    max_delta_step=1      # Sınıflar arası dengesizliği yönetir
)

# Parametre aralığı
param_grid = {
    'max_depth': [3, 5, 7],
    'learning_rate': [0.01, 0.1, 0.2],
    'n_estimators': [100, 200, 300],
    'subsample': [0.7, 0.8, 0.9],
    'colsample_bytree': [0.7, 0.8, 0.9]
}

#Eğitiyoruz
random_search = RandomizedSearchCV(
    estimator=xgb_model,
    param_distributions=param_grid,
    n_iter=20,
    cv=3,
    scoring='f1_weighted',
    verbose=0,
    n_jobs=1,
    random_state=42
)

print("\nYeni ayarlarla eğitim başlıyor...")
random_search.fit(x_train, y_train, sample_weight=sample_weights_array)

print("Eğitim tamamlandı.")
print("En iyi parametreler:", random_search.best_params_)

#Sonuçları değerlendirme kısmı
best_model = random_search.best_estimator_
y_pred = best_model.predict(x_test)

print("\nClassification Report:")
print(classification_report(y_test, y_pred))

# Confusion Matrix Görselleştirme
conf_matrix = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues',
            xticklabels=best_model.classes_,
            yticklabels=best_model.classes_)
plt.xlabel('Tahmin Edilen')
plt.ylabel('Gerçek Değer')
plt.title('Confusion Matrix (İyileştirilmiş Model)')
plt.show()
# Out:
# Orijinal Ağırlıklar: {np.int64(0): np.float64(1.0076180061964644), np.int64(1): np.float64(1.011655779400194), np.int64(2): np.float64(0.9812754024457342)}
# Güncellenmiş (Torpilli) Ağırlıklar: {np.int64(0): np.float64(1.0076180061964644), np.int64(1): np.float64(1.5174836691002909), np.int64(2): np.float64(0.9812754024457342)}
#
# Yeni ayarlarla eğitim başlıyor...
# Eğitim tamamlandı.
# En iyi parametreler: {'subsample': 0.8, 'n_estimators': 100, 'max_depth': 7, 'learning_rate': 0.1, 'colsample_bytree': 0.8}
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.92      0.92      0.92      1988
#            1       0.85      0.89      0.87      2051
#            2       0.97      0.92      0.95      2105
#
#     accuracy                           0.91      6144
#    macro avg       0.92      0.91      0.91      6144
# weighted avg       0.92      0.91      0.91      6144

# %%
# feature importances alıyoruz XGBoosttan
importances = best_model.feature_importances_
features = x_train.columns

# DataFrame oluştıuryoruz featurelar için
feature_importance_df = pd.DataFrame({'Feature': features, 'Importance': importances})

# ilk 15 öneme göre sıralıyoruz
top_features_xgb = feature_importance_df.sort_values(by='Importance', ascending=False).head(15)

# Plotting
plt.figure(figsize=(10, 8))
sns.barplot(x='Importance', y='Feature', data=top_features_xgb, palette='viridis')
plt.title('XGBoost Model - Top 15 Feature Importances')
plt.xlabel('Feature Importance')
plt.ylabel('Feature')
plt.tight_layout()
plt.show()

# %%
# 1. Feature Engineering Fonksiyonu
def apply_feature_engineering(df):
    df_fe = df.copy()

    # A. Kalite Puanı (Quality Score)
    # Olumlu yorumların toplam yorumlara oranı (0-1 arası)
    # Paydaya +1 ekliyoruz ki 0'a bölünme hatası olmasın
    df_fe['Quality_Score'] = df_fe['Positive'] / (df_fe['Positive'] + df_fe['Negative'] + 1)

    # B. Fiyat/Performans Skoru (Value Score)
    # Oynanış süresi başına ödenen ücret gibi düşünülebilir (Tersi: Bir dolar başına kaç saat oynanıyor)
    # Price + 1 diyerek ücretsiz oyunlarda hata almayı engelliyoruz.
    df_fe['Value_Score'] = df_fe['Average playtime forever'] / (df_fe['Price'] + 1)

    # C. Toplam Etkileşim (Review Volume - Log Transformlu)
    # Çok aşırı yorum alan oyunlar (Outlier) dengeyi bozmasın diye Log alıyoruz.
    df_fe['Review_Volume'] = np.log1p(df_fe['Positive'] + df_fe['Negative'])

    return df_fe

# 2. Mevcut x_train ve x_test verisine uygula
x_train_fe = apply_feature_engineering(x_train)
x_test_fe = apply_feature_engineering(x_test)

print("Feature engineering tamamlandı. Yeni özellikler eklendi.")
print("x_train_fe shape:", x_train_fe.shape)
print("x_test_fe shape:", x_test_fe.shape)

# Sınıf Ağırlıklarını Hesapla (Dengesiz veri seti için)
# (Önceki iterasyonda yapılan "Class 1" ağırlıklandırmasını tekrar uygulayalım)
class_weights_original = compute_class_weight(class_weight='balanced', classes=np.unique(y_train), y=y_train)
class_weight_dict = dict(zip(np.unique(y_train), class_weights_original))
class_weight_dict[1] = class_weight_dict[1] * 1.5 # Manually boost Class 1 weight
sample_weights_array = y_train.map(class_weight_dict)

# Model Hiperparametreleri Ayarlıyoruz
xgb_model_fe = xgb.XGBClassifier(
    random_state=42,
    tree_method='hist',
    device='cuda',
    use_label_encoder=False,
    eval_metric='mlogloss',
    max_delta_step=1 # Sınıflar arası dengesizliği yönetir
)

# Parametre aralığı (önceki ile aynı)
param_grid = {
    'max_depth': [3, 5, 7],
    'learning_rate': [0.01, 0.1, 0.2],
    'n_estimators': [100, 200, 300],
    'subsample': [0.7, 0.8, 0.9],
    'colsample_bytree': [0.7, 0.8, 0.9]
}

# RandomizedSearchCV Kurulumu (3-fold cross-validation)
random_search_fe = RandomizedSearchCV(
    estimator=xgb_model_fe,
    param_distributions=param_grid,
    n_iter=20,
    cv=3,
    scoring='f1_weighted',
    verbose=0,
    n_jobs=1,
    random_state=42
)

print("\nYeni özelliklerle ve 'Class 1' ağırlığı güçlendirilmiş şekilde eğitim başlıyor...")
# 3. Eğitimi Başlat
random_search_fe.fit(x_train_fe, y_train, sample_weight=sample_weights_array)

print("Eğitim tamamlandı.")
print("En iyi parametreler:", random_search_fe.best_params_)
print("En iyi skor (f1_weighted):", random_search_fe.best_score_)

# Sonuçları Değerlendirme
best_model_fe = random_search_fe.best_estimator_
y_pred_fe = best_model_fe.predict(x_test_fe)

print("\nFEATURE ENGINEERING + AĞIRLIKLI XGBoost SONUCU")
print("\nClassification Report:")
print(classification_report(y_test, y_pred_fe))

# Confusion Matrix Görselleştirme
conf_matrix_fe = confusion_matrix(y_test, y_pred_fe)
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix_fe, annot=True, fmt='d', cmap='Blues',
            xticklabels=best_model_fe.classes_,
            yticklabels=best_model_fe.classes_)
plt.xlabel('Tahmin Edilen')
plt.ylabel('Gerçek Değer')
plt.title('Confusion Matrix (FE + İyileştirilmiş XGBoost Modeli)')
plt.show()
# Out:
# Feature engineering tamamlandı. Yeni özellikler eklendi.
# x_train_fe shape: (55288, 43)
# x_test_fe shape: (6144, 43)
#
# Yeni özelliklerle ve 'Class 1' ağırlığı güçlendirilmiş şekilde eğitim başlıyor...
# Eğitim tamamlandı.
# En iyi parametreler: {'subsample': 0.7, 'n_estimators': 100, 'max_depth': 7, 'learning_rate': 0.1, 'colsample_bytree': 0.7}
# En iyi skor (f1_weighted): 0.9153248056631588
#
# FEATURE ENGINEERING + AĞIRLIKLI XGBoost SONUCU
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.92      0.93      0.92      1988
#            1       0.85      0.90      0.88      2051
#            2       0.98      0.92      0.95      2105
#
#     accuracy                           0.92      6144
#    macro avg       0.92      0.92      0.92      6144
# weighted avg       0.92      0.92      0.92      6144

# %%
# feature importances alıyoruz XGBoosttan
importances_fe = best_model_fe.feature_importances_
features_fe = x_train_fe.columns

# DataFrame oluştıuryoruz featurelar için
feature_importance_df_fe = pd.DataFrame({'Feature': features_fe, 'Importance': importances_fe})

# ilk 15 öneme göre sıralıyoruz
top_features_xgb_fe = feature_importance_df_fe.sort_values(by='Importance', ascending=False).head(15)

# Plotting
plt.figure(figsize=(10, 8))
sns.barplot(x='Importance', y='Feature', data=top_features_xgb_fe, palette='viridis') # Using a sequential palette
plt.title('XGBoost Model - Top 15 Feature Importances (After Feature Engineering)')
plt.xlabel('Feature Importance')
plt.ylabel('Feature')
plt.tight_layout()
plt.show()
